# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90,high=90,size=2000)
lngs = np.random.uniform(low=-180,high=180,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ae6d99df2a193d8c3f4c5cb1809ce300

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | ahuimanu
# Processing Record 3 of Set 1 | charters towers
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | umba
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | batticaloa
# Processing Record 8 of Set 1 | krasnyy chikoy
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | talnakh
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | isangel
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | san vicente
# Processing Record 23 of Set 1 | nabire
# Processing Record 24 of Set 1 | luganville
# Processing Record 25 of Set 1 | padang
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | chippewa falls
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | yulara
# Processing Record 33 of Set 1 | karratha
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 1 | camacupa
# Processing Record 38 of Set 1 | taltal
# Processing Record 39 of Set 1 | talaya
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | sandane
# Processing Record 42 of Set 1 | bathsheba
# Processing Record 43 of Set 1 | aksarka
# Processing Record 44 of Set 1 | ulladulla
# Processing Record 45 of Set 1 | zhangye
# Processing Record 46 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 1 | westport
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | laguna
# Processing Record 1 of Set 2 | coahuayana
# Processing Record 2 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 2 | chuy
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | jalu
# Processing Record 6 of Set 2 | mpanda
# Processing Record 7 of Set 2 | jamui
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | aranos
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | ponta do sol
# Processing Record 15 of Set 2 | christchurch
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | green river
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | fortuna
# Processing Record 20 of Set 2 | aklavik
# Processing Record 21 of Set 2 | kruisfontein
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | palu
# Processing Record 24 of Set 2 | locri
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | meulaboh
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | gornozavodsk
# Processing Record 33 of Set 2 | jacareacanga
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 2 | sundargarh
# Processing Record 37 of Set 2 | acapulco
# Processing Record 38 of Set 2 | omis
# Processing Record 39 of Set 2 | mapiripan
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | srednekolymsk
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | teguldet
# Processing Record 45 of Set 2 | chipinge
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | baykit
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | aswan
# Processing Record 50 of Set 2 | omboue
# Processing Record 1 of Set 3 | san jeronimo
# Processing Record 2 of Set 3 | warah
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | changji
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | fort nelson
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 3 | mayumba
# Processing Record 10 of Set 3 | mountain home
# Processing Record 11 of Set 3 | mount isa
# Processing Record 12 of Set 3 | odweyne
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | edremit
# Processing Record 16 of Set 3 | vaini
# Processing Record 17 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 3 | mecca
# Processing Record 19 of Set 3 | shrewsbury
# Processing Record 20 of Set 3 | shimoda
# Processing Record 21 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 3 | ambon
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | puerto leguizamo
# Processing Record 25 of Set 3 | callaguip
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | tezu
# Processing Record 28 of Set 3 | coihueco
# Processing Record 29 of Set 3 | caraquet
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | oistins
# Processing Record 35 of Set 3 | richards bay
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | nouakchott
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | lata
# Processing Record 41 of Set 3 | vieques
# Processing Record 42 of Set 3 | dekoa
# City not found. Skipping...
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | okhotsk
# Processing Record 45 of Set 3 | san cristobal
# Processing Record 46 of Set 3 | kavaratti
# Processing Record 47 of Set 3 | natitingou
# Processing Record 48 of Set 3 | khandyga
# Processing Record 49 of Set 3 | paamiut
# Processing Record 50 of Set 3 | olafsvik
# Processing Record 1 of Set 4 | champerico
# Processing Record 2 of Set 4 | lavrentiya
# Processing Record 3 of Set 4 | meadow lake
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | biloela
# Processing Record 6 of Set 4 | byron bay
# Processing Record 7 of Set 4 | labuhan
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | forest
# Processing Record 10 of Set 4 | teknaf
# Processing Record 11 of Set 4 | palmer
# Processing Record 12 of Set 4 | tommot
# Processing Record 13 of Set 4 | hovd
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | havelock
# Processing Record 16 of Set 4 | lake elsinore
# Processing Record 17 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 4 | muravlenko
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | auki
# Processing Record 22 of Set 4 | northam
# Processing Record 23 of Set 4 | esna
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | sistranda
# Processing Record 26 of Set 4 | zeya
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | saskylakh
# Processing Record 29 of Set 4 | alekseyevsk
# Processing Record 30 of Set 4 | manbij
# Processing Record 31 of Set 4 | maniitsoq
# Processing Record 32 of Set 4 | touros
# Processing Record 33 of Set 4 | abu samrah
# Processing Record 34 of Set 4 | altamont
# Processing Record 35 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 4 | gambela
# Processing Record 37 of Set 4 | hilo
# Processing Record 38 of Set 4 | naze
# Processing Record 39 of Set 4 | altay
# Processing Record 40 of Set 4 | sioux lookout
# Processing Record 41 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 4 | hambantota
# Processing Record 43 of Set 4 | tual
# Processing Record 44 of Set 4 | carutapera
# Processing Record 45 of Set 4 | the valley
# Processing Record 46 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 4 | riachao das neves
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | luanda
# Processing Record 50 of Set 4 | la asuncion
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | tokur
# Processing Record 3 of Set 5 | gusau
# Processing Record 4 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 5 of Set 5 | montalvo
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | ladario
# Processing Record 8 of Set 5 | black river
# Processing Record 9 of Set 5 | sawtell
# Processing Record 10 of Set 5 | lubango
# Processing Record 11 of Set 5 | minsk
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | cayenne
# Processing Record 14 of Set 5 | port macquarie
# Processing Record 15 of Set 5 | oriximina
# Processing Record 16 of Set 5 | lodja
# Processing Record 17 of Set 5 | aktau
# Processing Record 18 of Set 5 | nicoya
# Processing Record 19 of Set 5 | biak
# Processing Record 20 of Set 5 | grindavik
# Processing Record 21 of Set 5 | brockville
# Processing Record 22 of Set 5 | abbeville
# Processing Record 23 of Set 5 | kirkuk
# Processing Record 24 of Set 5 | la rioja
# Processing Record 25 of Set 5 | provideniya
# Processing Record 26 of Set 5 | corvallis
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | aquiraz
# Processing Record 29 of Set 5 | sarai naurang
# Processing Record 30 of Set 5 | paratinga
# Processing Record 31 of Set 5 | vanavara
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | praia da vitoria
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | aanekoski
# Processing Record 36 of Set 5 | port keats
# Processing Record 37 of Set 5 | bela
# Processing Record 38 of Set 5 | mackay
# Processing Record 39 of Set 5 | port-gentil
# Processing Record 40 of Set 5 | mehamn
# Processing Record 41 of Set 5 | santa marta
# Processing Record 42 of Set 5 | ahipara
# Processing Record 43 of Set 5 | east london
# Processing Record 44 of Set 5 | hasaki
# Processing Record 45 of Set 5 | naron
# Processing Record 46 of Set 5 | guymon
# Processing Record 47 of Set 5 | miri
# Processing Record 48 of Set 5 | kavieng
# Processing Record 49 of Set 5 | kahului
# Processing Record 50 of Set 5 | ola
# Processing Record 1 of Set 6 | changying
# Processing Record 2 of Set 6 | menongue
# Processing Record 3 of Set 6 | tonj
# Processing Record 4 of Set 6 | atbasar
# Processing Record 5 of Set 6 | avera
# Processing Record 6 of Set 6 | springfield
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | la virginia
# Processing Record 9 of Set 6 | severo-kurilsk
# Processing Record 10 of Set 6 | upernavik
# Processing Record 11 of Set 6 | owase
# Processing Record 12 of Set 6 | burnie
# Processing Record 13 of Set 6 | lasa
# Processing Record 14 of Set 6 | chapais
# Processing Record 15 of Set 6 | rio gallegos
# Processing Record 16 of Set 6 | poum
# Processing Record 17 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 6 | guasdualito
# Processing Record 19 of Set 6 | nkhotakota
# Processing Record 20 of Set 6 | manono
# Processing Record 21 of Set 6 | kalinovo
# Processing Record 22 of Set 6 | ouesso
# Processing Record 23 of Set 6 | rawson
# Processing Record 24 of Set 6 | huimilpan
# Processing Record 25 of Set 6 | malakal
# Processing Record 26 of Set 6 | fredericksburg
# Processing Record 27 of Set 6 | mehran
# Processing Record 28 of Set 6 | ashland
# Processing Record 29 of Set 6 | sibolga
# Processing Record 30 of Set 6 | dikson
# Processing Record 31 of Set 6 | shelburne
# Processing Record 32 of Set 6 | port augusta
# Processing Record 33 of Set 6 | mirabela
# Processing Record 34 of Set 6 | yatou
# Processing Record 35 of Set 6 | calderitas
# Processing Record 36 of Set 6 | salalah
# Processing Record 37 of Set 6 | shestakovo
# Processing Record 38 of Set 6 | conceicao do araguaia
# Processing Record 39 of Set 6 | buzmeyin
# Processing Record 40 of Set 6 | hami
# Processing Record 41 of Set 6 | mana
# Processing Record 42 of Set 6 | juuru
# Processing Record 43 of Set 6 | plouzane
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | college
# Processing Record 46 of Set 6 | kaputa
# Processing Record 47 of Set 6 | staffanstorp
# Processing Record 48 of Set 6 | bethel
# Processing Record 49 of Set 6 | savelugu
# Processing Record 50 of Set 6 | kirakira
# Processing Record 1 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 7 | chikmagalur
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | hun
# Processing Record 5 of Set 7 | progreso
# Processing Record 6 of Set 7 | kurush
# Processing Record 7 of Set 7 | vila
# Processing Record 8 of Set 7 | kostomuksha
# Processing Record 9 of Set 7 | tasiilaq
# Processing Record 10 of Set 7 | esperance
# Processing Record 11 of Set 7 | porbandar
# Processing Record 12 of Set 7 | khani
# Processing Record 13 of Set 7 | les cayes
# Processing Record 14 of Set 7 | dwarka
# Processing Record 15 of Set 7 | vardo
# Processing Record 16 of Set 7 | port elizabeth
# Processing Record 17 of Set 7 | quatre cocos
# Processing Record 18 of Set 7 | moba
# Processing Record 19 of Set 7 | marsh harbour
# Processing Record 20 of Set 7 | lorengau
# Processing Record 21 of Set 7 | tashla
# Processing Record 22 of Set 7 | nanortalik
# Processing Record 23 of Set 7 | upata
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 7 | stephenville
# Processing Record 27 of Set 7 | luoyang
# Processing Record 28 of Set 7 | chicama
# Processing Record 29 of Set 7 | caravelas
# Processing Record 30 of Set 7 | phalombe
# Processing Record 31 of Set 7 | kaduy
# Processing Record 32 of Set 7 | tocopilla
# Processing Record 33 of Set 7 | benidorm
# Processing Record 34 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | tiarei
# Processing Record 37 of Set 7 | damaturu
# Processing Record 38 of Set 7 | moerai
# Processing Record 39 of Set 7 | malatya
# Processing Record 40 of Set 7 | leshukonskoye
# Processing Record 41 of Set 7 | wajir
# Processing Record 42 of Set 7 | beringovskiy
# Processing Record 43 of Set 7 | kaffrine
# Processing Record 44 of Set 7 | tilichiki
# Processing Record 45 of Set 7 | leningradskiy
# Processing Record 46 of Set 7 | bozhou
# Processing Record 47 of Set 7 | tyukhtet
# Processing Record 48 of Set 7 | tortosa
# Processing Record 49 of Set 7 | banda aceh
# Processing Record 50 of Set 7 | kyzyl
# Processing Record 1 of Set 8 | lohja
# Processing Record 2 of Set 8 | gumla
# Processing Record 3 of Set 8 | kamaishi
# Processing Record 4 of Set 8 | tsiroanomandidy
# Processing Record 5 of Set 8 | cururupu
# Processing Record 6 of Set 8 | abay
# Processing Record 7 of Set 8 | porosozero
# Processing Record 8 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 8 | puunsi
# City not found. Skipping...
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | diapaga
# Processing Record 12 of Set 8 | kununurra
# Processing Record 13 of Set 8 | deputatskiy
# Processing Record 14 of Set 8 | kichera
# Processing Record 15 of Set 8 | banes
# Processing Record 16 of Set 8 | lensk
# Processing Record 17 of Set 8 | sena madureira
# Processing Record 18 of Set 8 | egvekinot
# Processing Record 19 of Set 8 | slave lake
# Processing Record 20 of Set 8 | opuwo
# Processing Record 21 of Set 8 | paducah
# Processing Record 22 of Set 8 | grand gaube
# Processing Record 23 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | kaeo
# Processing Record 25 of Set 8 | roald
# Processing Record 26 of Set 8 | suntar
# Processing Record 27 of Set 8 | neiafu
# Processing Record 28 of Set 8 | swan river
# Processing Record 29 of Set 8 | mogadishu
# Processing Record 30 of Set 8 | egra
# Processing Record 31 of Set 8 | coihaique
# Processing Record 32 of Set 8 | melo
# Processing Record 33 of Set 8 | cortez
# Processing Record 34 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 35 of Set 8 | talakan
# Processing Record 36 of Set 8 | minab
# Processing Record 37 of Set 8 | annau
# Processing Record 38 of Set 8 | san carlos de bariloche
# Processing Record 39 of Set 8 | lasem
# Processing Record 40 of Set 8 | beitbridge
# Processing Record 41 of Set 8 | betsiamites
# Processing Record 42 of Set 8 | bilibino
# Processing Record 43 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 8 | kargasok
# Processing Record 45 of Set 8 | winton
# Processing Record 46 of Set 8 | la ronge
# Processing Record 47 of Set 8 | fukue
# Processing Record 48 of Set 8 | shitanjing
# Processing Record 49 of Set 8 | manali
# Processing Record 50 of Set 8 | tongling
# Processing Record 1 of Set 9 | isla vista
# Processing Record 2 of Set 9 | zhezkazgan
# Processing Record 3 of Set 9 | sabang
# Processing Record 4 of Set 9 | trairi
# Processing Record 5 of Set 9 | dingle
# Processing Record 6 of Set 9 | mansa
# Processing Record 7 of Set 9 | inongo
# Processing Record 8 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 9 | ramon castilla
# Processing Record 10 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 9 | songjianghe
# Processing Record 12 of Set 9 | pangnirtung
# Processing Record 13 of Set 9 | ustka
# Processing Record 14 of Set 9 | coulihaut
# City not found. Skipping...
# Processing Record 15 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 9 | dunedin
# Processing Record 17 of Set 9 | iqaluit
# Processing Record 18 of Set 9 | nantucket
# Processing Record 19 of Set 9 | lichinga
# Processing Record 20 of Set 9 | vestmannaeyjar
# Processing Record 21 of Set 9 | pabna
# Processing Record 22 of Set 9 | vilhena
# Processing Record 23 of Set 9 | lagoa
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | verkhnyaya inta
# Processing Record 26 of Set 9 | oranjemund
# Processing Record 27 of Set 9 | portland
# Processing Record 28 of Set 9 | san juan
# Processing Record 29 of Set 9 | sakaiminato
# Processing Record 30 of Set 9 | poyarkovo
# Processing Record 31 of Set 9 | port hedland
# Processing Record 32 of Set 9 | severo-yeniseyskiy
# Processing Record 33 of Set 9 | faanui
# Processing Record 34 of Set 9 | hobyo
# Processing Record 35 of Set 9 | togur
# Processing Record 36 of Set 9 | chernyshevskiy
# Processing Record 37 of Set 9 | roma
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | pryozerne
# Processing Record 40 of Set 9 | half moon bay
# Processing Record 41 of Set 9 | maldonado
# Processing Record 42 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 43 of Set 9 | sept-iles
# Processing Record 44 of Set 9 | batagay
# Processing Record 45 of Set 9 | kokopo
# Processing Record 46 of Set 9 | tazovskiy
# Processing Record 47 of Set 9 | haines junction
# Processing Record 48 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 9 | pisco
# Processing Record 50 of Set 9 | mchinji
# Processing Record 1 of Set 10 | beni
# Processing Record 2 of Set 10 | nhulunbuy
# Processing Record 3 of Set 10 | ust-omchug
# Processing Record 4 of Set 10 | luancheng
# Processing Record 5 of Set 10 | sinnar
# Processing Record 6 of Set 10 | waipawa
# Processing Record 7 of Set 10 | ulaanbaatar
# Processing Record 8 of Set 10 | kloulklubed
# Processing Record 9 of Set 10 | saint-augustin
# Processing Record 10 of Set 10 | bambanglipuro
# Processing Record 11 of Set 10 | kholodnyy
# Processing Record 12 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 10 | nileshwar
# Processing Record 14 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 10 | spas-demensk
# Processing Record 16 of Set 10 | axim
# Processing Record 17 of Set 10 | birao
# Processing Record 18 of Set 10 | kaitangata
# Processing Record 19 of Set 10 | lazurne
# Processing Record 20 of Set 10 | lake havasu city
# Processing Record 21 of Set 10 | paralimni
# Processing Record 22 of Set 10 | bria
# Processing Record 23 of Set 10 | hengyang
# Processing Record 24 of Set 10 | ebeltoft
# Processing Record 25 of Set 10 | magdalena
# Processing Record 26 of Set 10 | mareeba
# Processing Record 27 of Set 10 | arrecife
# Processing Record 28 of Set 10 | matamoros
# Processing Record 29 of Set 10 | atar
# Processing Record 30 of Set 10 | ketchikan
# Processing Record 31 of Set 10 | eirunepe
# Processing Record 32 of Set 10 | prince rupert
# Processing Record 33 of Set 10 | norsup
# Processing Record 34 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 35 of Set 10 | hinesburg
# Processing Record 36 of Set 10 | mwinilunga
# Processing Record 37 of Set 10 | mounana
# Processing Record 38 of Set 10 | ilulissat
# Processing Record 39 of Set 10 | emirdag
# Processing Record 40 of Set 10 | san patricio
# Processing Record 41 of Set 10 | moron
# Processing Record 42 of Set 10 | kangaba
# Processing Record 43 of Set 10 | fenyi
# Processing Record 44 of Set 10 | redlands
# Processing Record 45 of Set 10 | lamu
# Processing Record 46 of Set 10 | arlit
# Processing Record 47 of Set 10 | saryozek
# Processing Record 48 of Set 10 | fengrun
# Processing Record 49 of Set 10 | saldanha
# Processing Record 50 of Set 10 | alenquer
# Processing Record 1 of Set 11 | collie
# Processing Record 2 of Set 11 | gidole
# Processing Record 3 of Set 11 | store heddinge
# Processing Record 4 of Set 11 | vibo valentia
# Processing Record 5 of Set 11 | zasheyek
# Processing Record 6 of Set 11 | pinega
# Processing Record 7 of Set 11 | dole
# Processing Record 8 of Set 11 | karasjok
# Processing Record 9 of Set 11 | tautira
# Processing Record 10 of Set 11 | south lake tahoe
# Processing Record 11 of Set 11 | namie
# Processing Record 12 of Set 11 | lethbridge
# Processing Record 13 of Set 11 | constitucion
# Processing Record 14 of Set 11 | vanderhoof
# Processing Record 15 of Set 11 | madaoua
# Processing Record 16 of Set 11 | ostrovnoy
# Processing Record 17 of Set 11 | sao filipe
# Processing Record 18 of Set 11 | saint anthony
# Processing Record 19 of Set 11 | gotsu
# Processing Record 20 of Set 11 | inhambane
# Processing Record 21 of Set 11 | billings
# Processing Record 22 of Set 11 | skjervoy
# Processing Record 23 of Set 11 | goderich
# Processing Record 24 of Set 11 | tres picos
# Processing Record 25 of Set 11 | akhnur
# Processing Record 26 of Set 11 | santa isabel do rio negro
# Processing Record 27 of Set 11 | evensk
# Processing Record 28 of Set 11 | saint-francois
# Processing Record 29 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 11 | xichang
# Processing Record 31 of Set 11 | sorong
# Processing Record 32 of Set 11 | caucaia
# Processing Record 33 of Set 11 | birobidzhan
# Processing Record 34 of Set 11 | makaha
# Processing Record 35 of Set 11 | vostok
# Processing Record 36 of Set 11 | crib point
# Processing Record 37 of Set 11 | saint-paul
# Processing Record 38 of Set 11 | tome-acu
# City not found. Skipping...
# Processing Record 39 of Set 11 | shakawe
# Processing Record 40 of Set 11 | digha
# Processing Record 41 of Set 11 | monze
# Processing Record 42 of Set 11 | ilo
# Processing Record 43 of Set 11 | yeppoon
# Processing Record 44 of Set 11 | marawi
# Processing Record 45 of Set 11 | conway
# Processing Record 46 of Set 11 | cherskiy
# Processing Record 47 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 11 | brigg
# Processing Record 49 of Set 11 | metro
# Processing Record 50 of Set 11 | buala
# Processing Record 1 of Set 12 | huangnihe
# Processing Record 2 of Set 12 | brewster
# Processing Record 3 of Set 12 | sassandra
# Processing Record 4 of Set 12 | ponta delgada
# Processing Record 5 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 12 | phu ly
# Processing Record 7 of Set 12 | muisne
# Processing Record 8 of Set 12 | minudasht
# Processing Record 9 of Set 12 | sabha
# Processing Record 10 of Set 12 | porto novo
# Processing Record 11 of Set 12 | asfi
# Processing Record 12 of Set 12 | yumen
# Processing Record 13 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 12 | pundaguitan
# Processing Record 16 of Set 12 | manokwari
# Processing Record 17 of Set 12 | agadir
# Processing Record 18 of Set 12 | jequie
# Processing Record 19 of Set 12 | moose factory
# Processing Record 20 of Set 12 | itarema
# Processing Record 21 of Set 12 | souillac
# Processing Record 22 of Set 12 | nishihara
# Processing Record 23 of Set 12 | cairns
# Processing Record 24 of Set 12 | maarianhamina
# Processing Record 25 of Set 12 | nizhniy kuranakh
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | san onofre
# Processing Record 28 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 12 | tutoia
# Processing Record 30 of Set 12 | teya
# Processing Record 31 of Set 12 | honiara
# Processing Record 32 of Set 12 | staroye drozhzhanoye
# Processing Record 33 of Set 12 | anloga
# Processing Record 34 of Set 12 | wanaka
# Processing Record 35 of Set 12 | port hardy
# Processing Record 36 of Set 12 | ende
# Processing Record 37 of Set 12 | damietta
# Processing Record 38 of Set 12 | camrose
# Processing Record 39 of Set 12 | alofi
# Processing Record 40 of Set 12 | baherden
# Processing Record 41 of Set 12 | sobolevo
# Processing Record 42 of Set 12 | creel
# Processing Record 43 of Set 12 | tasca
# Processing Record 44 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 12 | karlskoga
# Processing Record 46 of Set 12 | murud
# Processing Record 47 of Set 12 | riyadh
# Processing Record 48 of Set 12 | kiama
# Processing Record 49 of Set 12 | san jose
# Processing Record 50 of Set 12 | muscat
# Processing Record 1 of Set 13 | mezen
# Processing Record 2 of Set 13 | aykhal
# Processing Record 3 of Set 13 | sault sainte marie
# Processing Record 4 of Set 13 | ziarat
# Processing Record 5 of Set 13 | huaraz
# Processing Record 6 of Set 13 | san luis
# Processing Record 7 of Set 13 | pauini
# Processing Record 8 of Set 13 | ondjiva
# Processing Record 9 of Set 13 | maumere
# Processing Record 10 of Set 13 | covington
# Processing Record 11 of Set 13 | olga
# Processing Record 12 of Set 13 | denpasar
# Processing Record 13 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 13 | grafton
# Processing Record 15 of Set 13 | fandriana
# Processing Record 16 of Set 13 | marzuq
# Processing Record 17 of Set 13 | stantsionno-oyashinskiy
# Processing Record 18 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 19 of Set 13 | amga
# Processing Record 20 of Set 13 | barranca
# Processing Record 21 of Set 13 | forbes
# Processing Record 22 of Set 13 | anadyr
# Processing Record 23 of Set 13 | kakinada
# Processing Record 24 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 13 | nynashamn
# Processing Record 26 of Set 13 | narsaq
# Processing Record 27 of Set 13 | inuvik
# Processing Record 28 of Set 13 | matara
# Processing Record 29 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 30 of Set 13 | north bend
# Processing Record 31 of Set 13 | tombouctou
# Processing Record 32 of Set 13 | brownsville
# Processing Record 33 of Set 13 | katobu
# Processing Record 34 of Set 13 | otradnoye
# Processing Record 35 of Set 13 | mugur-aksy
# Processing Record 36 of Set 13 | gwadar
# Processing Record 37 of Set 13 | alyangula
# Processing Record 38 of Set 13 | niquelandia
# Processing Record 39 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 13 | necochea
# Processing Record 41 of Set 13 | mortka
# Processing Record 42 of Set 13 | pandan
# Processing Record 43 of Set 13 | dongobesh
# Processing Record 44 of Set 13 | darhan
# Processing Record 45 of Set 13 | hay river
# Processing Record 46 of Set 13 | krasnozerskoye
# Processing Record 47 of Set 13 | codrington
# Processing Record 48 of Set 13 | belgrade
# Processing Record 49 of Set 13 | podor
# Processing Record 50 of Set 13 | villefontaine
# Processing Record 1 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 14 | san quintin
# Processing Record 3 of Set 14 | boca do acre
# Processing Record 4 of Set 14 | kupang
# Processing Record 5 of Set 14 | gorom-gorom
# Processing Record 6 of Set 14 | bulawayo
# Processing Record 7 of Set 14 | terrasini
# Processing Record 8 of Set 14 | urucara
# Processing Record 9 of Set 14 | fairbanks
# Processing Record 10 of Set 14 | mount vernon
# Processing Record 11 of Set 14 | pochutla
# Processing Record 12 of Set 14 | trelew
# Processing Record 13 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 14 | koungou
# Processing Record 15 of Set 14 | gombong
# Processing Record 16 of Set 14 | asosa
# Processing Record 17 of Set 14 | dhidhdhoo
# Processing Record 18 of Set 14 | linshu
# City not found. Skipping...
# Processing Record 19 of Set 14 | pokhara
# Processing Record 20 of Set 14 | vao
# Processing Record 21 of Set 14 | trat
# Processing Record 22 of Set 14 | batagay-alyta
# Processing Record 23 of Set 14 | terni
# Processing Record 24 of Set 14 | beloha
# Processing Record 25 of Set 14 | olinda
# Processing Record 26 of Set 14 | salta
# Processing Record 27 of Set 14 | saint-pierre
# Processing Record 28 of Set 14 | sabla
# Processing Record 29 of Set 14 | xinqing
# Processing Record 30 of Set 14 | gualaquiza
# Processing Record 31 of Set 14 | praia
# Processing Record 32 of Set 14 | filadelfia
# Processing Record 33 of Set 14 | yazd
# Processing Record 34 of Set 14 | sur
# Processing Record 35 of Set 14 | aitape
# Processing Record 36 of Set 14 | talcahuano
# Processing Record 37 of Set 14 | thyolo
# Processing Record 38 of Set 14 | mildura
# Processing Record 39 of Set 14 | san fernando
# Processing Record 40 of Set 14 | usinsk
# Processing Record 41 of Set 14 | nome
# Processing Record 42 of Set 14 | innisfail
# Processing Record 43 of Set 14 | bilecik
# Processing Record 44 of Set 14 | ust-koksa
# Processing Record 45 of Set 14 | kitui
# Processing Record 46 of Set 14 | holguin
# Processing Record 47 of Set 14 | lazaro cardenas
# Processing Record 48 of Set 14 | arona
# Processing Record 49 of Set 14 | akdepe
# Processing Record 50 of Set 14 | borama
# City not found. Skipping...
# Processing Record 1 of Set 15 | vangaindrano
# Processing Record 2 of Set 15 | yerofey pavlovich
# Processing Record 3 of Set 15 | sansai
# City not found. Skipping...
# Processing Record 4 of Set 15 | lebanon
# Processing Record 5 of Set 15 | zlatoustovsk
# City not found. Skipping...
# Processing Record 6 of Set 15 | manicore
# Processing Record 7 of Set 15 | mkushi
# Processing Record 8 of Set 15 | buchanan
# Processing Record 9 of Set 15 | damara
# Processing Record 10 of Set 15 | ocean city
# Processing Record 11 of Set 15 | besikduzu
# Processing Record 12 of Set 15 | ha tinh
# Processing Record 13 of Set 15 | torbat-e jam
# Processing Record 14 of Set 15 | tuatapere
# Processing Record 15 of Set 15 | warrington
# Processing Record 16 of Set 15 | caboolture
# Processing Record 17 of Set 15 | general roca
# Processing Record 18 of Set 15 | blagoyevo
# Processing Record 19 of Set 15 | nemuro
# Processing Record 20 of Set 15 | flinders
# Processing Record 21 of Set 15 | corrales
# Processing Record 22 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 23 of Set 15 | millbury
# Processing Record 24 of Set 15 | jacobina
# Processing Record 25 of Set 15 | gizo
# Processing Record 26 of Set 15 | rochegda
# Processing Record 27 of Set 15 | saint-joseph
# Processing Record 28 of Set 15 | saint-denis
# Processing Record 29 of Set 15 | gravata
# Processing Record 30 of Set 15 | shaoguan
# Processing Record 31 of Set 15 | coquimbo
# Processing Record 32 of Set 15 | pascagoula
# Processing Record 33 of Set 15 | komsomolskiy
# Processing Record 34 of Set 15 | kansanshi
# Processing Record 35 of Set 15 | monroe
# Processing Record 36 of Set 15 | pastavy
# Processing Record 37 of Set 15 | ayan
# Processing Record 38 of Set 15 | teguise
# Processing Record 39 of Set 15 | skibbereen
# Processing Record 40 of Set 15 | broome
# Processing Record 41 of Set 15 | cheremukhovo
# Processing Record 42 of Set 15 | novyy urengoy
# Processing Record 43 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 15 | craig
# Processing Record 45 of Set 15 | ouadda
# Processing Record 46 of Set 15 | asyut
# Processing Record 47 of Set 15 | bonthe
# Processing Record 48 of Set 15 | zabaykalsk
# Processing Record 49 of Set 15 | kjopsvik
# Processing Record 50 of Set 15 | oeiras
# Processing Record 1 of Set 16 | navahrudak
# Processing Record 2 of Set 16 | sherpur
# Processing Record 3 of Set 16 | ust-kuyga
# Processing Record 4 of Set 16 | huangmei
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0          Qaanaaq      GL  2022-09-24 03:45:56  77.4840  -69.3632     10.81
# 1         Ahuimanu      US  2022-09-24 03:45:57  21.4447 -157.8378     82.11
# 2  Charters Towers      AU  2022-09-24 03:45:57 -20.1000  146.2667     87.66
# 3           Lompoc      US  2022-09-24 03:45:58  34.6391 -120.4579     70.02
# 4             Umba      RU  2022-09-24 03:45:58  66.6871   34.3429     45.79
# 5      Tuktoyaktuk      CA  2022-09-24 03:45:59  69.4541 -133.0374     33.80
# 6       Batticaloa      LK  2022-09-24 03:45:59   7.7102   81.6924     85.10
# 7   Krasnyy Chikoy      RU  2022-09-24 03:45:59  50.3643  108.7512     47.68
# 8     Punta Arenas      CL  2022-09-24 03:43:24 -53.1500  -70.9167     39.31
# 9          Mataura      NZ  2022-09-24 03:46:00 -46.1927  168.8643     59.54
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        79          59        6.89       broken clouds
# 1        73          40        6.91    scattered clouds
# 2        27           0        2.04           clear sky
# 3        95           0        0.00                mist
# 4        89         100        6.93     overcast clouds
# 5        86         100       10.36     overcast clouds
# 6        56         100        1.79     overcast clouds
# 7        76         100        2.19     overcast clouds
# 8        75           0       10.36           clear sky
# 9        55          85        5.03     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
